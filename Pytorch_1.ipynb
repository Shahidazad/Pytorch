# %%
import torch

# %%
t1=torch.tensor(4.)

# %%
t1 #number
# Out:
# tensor(4.)

# %%
t1.dtype
# Out:
# torch.float32

# %%
t2=torch.tensor([1.,2,3,4]) # same data type

# %%
t2
# Out:
# tensor([1., 2., 3., 4.])

# %%
# matrix
t3=torch.tensor([[5.6],[7,8],[9,10]])
t3
# Out:
# tensor([[ 5.,  6.],
#         [ 7.,  8.],
#         [ 9., 10.]])

# %%
t4=torch.tensor([
                 [[11,12,13],
                  [13,14,15]],
                 [[15,16,17],
                  [17,18,19.]]])

# %%
t4.shape
# Out:
# torch.Size([2, 2, 3])

# %%
t1.shape #number
# Out:
# torch.Size([])

# %%
t2.shape # vector
# Out:
# torch.Size([4])

# %%
t3.shape # matrix
# Out:
# torch.Size([3, 2])

# %%
 #create tensor
 x=torch.tensor(3.)
 w=torch.tensor(4.,requires_grad=True)
 b=torch.tensor(5.,requires_grad=True)

# %%
y= w*x+b
y
# Out:
# tensor(17., grad_fn=<AddBackward0>)

# %%
y.backward() # compute derivative use for optimization alg(gradient desecent)

# %%
print('dy/dx',x.grad) # requires grad None
print('dy/dw',w.grad)# true
print('dy/db',b.grad)
# Out:
# dy/dx None
# dy/dw tensor(3.)
# dy/db tensor(1.)

# %%
x
# Out:
# tensor(3.)

# %%
import numpy as np
x=np.array([[1,2],[3,4.]])
x
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
# convt numpy  to tensor
y=torch.from_numpy(x)

# %%
y
# Out:
# tensor([[1., 2.],
#         [3., 4.]], dtype=torch.float64)

# %%
# convt tensor to numpy
z=y.numpy()

# %%
z
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
# pytorch use GPU it is fast

# %%
# Training data
#input (temp , rain ,humidity)
inputs=np.array([[73, 67, 43], 
                   [91, 88, 64], 
                   [87, 134, 58], 
                   [102, 43, 37], 
                   [69, 96, 70]], dtype='float32')

# %%
# Target data (apple,oranges)
targets = np.array([[56, 70], 
                    [81, 101], 
                    [119, 133], 
                    [22, 37], 
                    [103, 119]], dtype='float32')

# %%
# convt to tensor
inputs=torch.from_numpy(inputs)
targets=torch.from_numpy(targets)

# %%
# weight and bias
w=torch.randn(2,3,requires_grad=True) # 2,rows 3 columns # matrix
b=torch.randn(2,requires_grad=True) # vector
print(w)
b
# Out:
# tensor([[ 1.7865e+00, -4.0421e-04, -3.8661e-01],
#         [ 6.7550e-01,  1.0447e+00,  9.4444e-01]], requires_grad=True)
# tensor([-1.2845, -0.6817], requires_grad=True)

# %%
def model(x):
  return x @  w.t() +b  # x @(multiple) w.t(weight transpose matrix) b(bias)(vector)

# %%
# prediction
preds = model(inputs)
print(preds)
# Out:
# tensor([[112.4803, 159.2379],
#         [136.5105, 213.1695],
#         [131.6654, 252.8583],
#         [166.6187, 148.0874],
#         [ 94.8842, 212.3328]], grad_fn=<AddBackward0>)

# %%
targets
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])

# %%
diff =preds  - targets
diff_sqr=diff**2
diff_sqr
# Out:
# tensor([[ 3190.0278,  7963.3945],
#         [ 3081.4138, 12581.9922],
#         [  160.4133, 14366.0098],
#         [20914.5762, 12340.4004],
#         [   65.8664,  8711.0186]], grad_fn=<PowBackward0>)

# %%
# MSR loss
def mse(t1,t2):
  diff = t1-t2
  return torch.sum(diff**2) / diff.numel()

# %%
# compute loss
loss= mse(preds,targets)
loss    # very bad
# Out:
# tensor(8337.5107, grad_fn=<DivBackward0>)

# %%
# compute gradient 

loss.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-d6deb7a94d90> in <module>()
#       1 # compute gradient
#       2
# ----> 3 loss.backward()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     361                 create_graph=create_graph,
#     362                 inputs=inputs)
# --> 363         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     364
#     365     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# ...

# %%
print(w)
print(w.grad)
# Out:
# tensor([[ 1.7865e+00, -4.0421e-04, -3.8661e-01],
#         [ 6.7550e-01,  1.0447e+00,  9.4444e-01]], requires_grad=True)
# tensor([[4893.5063, 3161.1519, 2299.7415],
#         [8984.0674, 9129.5137, 5722.2773]])
